# %% [raw]
# """
# Author: Hannes Rosseel
#
# This demo file shows how to generate an Exponential Sine Sweep (ESS) and its
# inverse filter according to Farina [1] and how to calculate a Room Impulse
# Response (RIR) from a measured sweep.
#
# Do not disseminate this code without permission.
# """
#
# ###############################################################################
# # Import required libraries
# ###############################################################################

# %%
import numpy as np
import matplotlib.pyplot as plt
import soundfile as sf
import os

from lib import ess_gen_farina, ess_parse_farina

# %% [raw]
# ###############################################################################
# # Create Exponential Sine Sweep from parameters
# ###############################################################################

# %%
fs = 48000  # Sampling Frequency [Hz]

f1 = 20  # Initial frequency [Hz]
f2 = 20000  # Final frequency [Hz]

T_sweep = 10  # Sweep duration [sec.]
T_idle = 3  # Idle duration [sec.]

fade_in = int(0.100 * fs)  # fade-in window of 100 ms [samples]

t_sweep = np.arange(0, (T_sweep + T_idle) * fs) / fs  # Time vector [sec.]

# %% [raw]
# ###############################################################################
# # Generate exponential sine sweep and its inverse filter
# ###############################################################################

# %%
sweep, inverse = ess_gen_farina(f1, f2, T_sweep, T_idle, fs,
                                fade_in=fade_in,
                                cut_zerocross=True)
# Out:
# Warning: sweep cutoff at last zero-crossing. Final frequency is: 19998 Hz

# %% [raw]
# ###############################################################################
# # Plot the generated sweep and inverse filter
# ###############################################################################

# %%
fig, axs = plt.subplots(2, 1, figsize=(10, 5), sharex=True)
axs[0].plot(t_sweep, sweep)
axs[0].set_title('Exponential Sine Sweep $x(t)$')
axs[0].set_xlabel('Time [s]')
axs[0].set_ylabel('Amplitude')
axs[0].grid()

axs[1].plot(np.arange(0, int(T_sweep * fs)) / fs, inverse)
axs[1].set_title('Inverse Filter $\\tilde{x}(t)$')
axs[1].set_xlabel('Time [s]')
axs[1].set_ylabel('Amplitude')
axs[1].grid()
fig.tight_layout()

# %% [raw]
# ###############################################################################
# # Perform deconvolution with measured sweep
# # For this demo, we use the generated sweep as measured sweep
# ###############################################################################

# %%
#loop over all wav files in this folder and its subfolders
for root, dirs, files in os.walk(os.getcwd()):
    for file in files:
        if file.endswith(".wav"):
            #read the wav file
            measured_sweep = sf.read(os.path.join(root, file))[0]
            
            #perform deconvolution
            h = ess_parse_farina(measured_sweep, inverse, T_sweep, T_idle, fs, causality=True)

            #save the RIR
            sf.write(os.path.join(root, file[:-4] + '_RIR.wav'), h, fs, subtype='PCM_24')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/gijsf/Documents/SPAI/repo/WAVFiles/Sweeps/6MIC/sweep_generation.ipynb Cell 10 line 9
#       <a href='vscode-notebook-cell:/home/gijsf/Documents/SPAI/repo/WAVFiles/Sweeps/6MIC/sweep_generation.ipynb#X20sZmlsZQ%3D%3D?line=5'>6</a> measured_sweep = sf.read(os.path.join(root, file))
#       <a href='vscode-notebook-cell:/home/gijsf/Documents/SPAI/repo/WAVFiles/Sweeps/6MIC/sweep_generation.ipynb#X20sZmlsZQ%3D%3D?line=7'>8</a> #perform deconvolution
# ----> <a href='vscode-notebook-cell:/home/gijsf/Documents/SPAI/repo/WAVFiles/Sweeps/6MIC/sweep_generation.ipynb#X20sZmlsZQ%3D%3D?line=8'>9</a> h = ess_parse_farina(measured_sweep, inverse, T_sweep, T_idle, fs, causality=True)
#      <a href='vscode-notebook-cell:/home/gijsf/Documents/SPAI/repo/WAVFiles/Sweeps/6MIC/sweep_generation.ipynb#X20sZmlsZQ%3D%3D?line=10'>11</a> #save the RIR
#      <a href='vscode-notebook-cell:/home/gijsf/Documents/SPAI/repo/WAVFiles/Sweeps/6MIC/sweep_generation.ipynb#X20sZmlsZQ%3D%3D?line=11'>12</a> sf.write(os.path.join(root, file[:-4] + '_RIR.wav'), h, fs, subtype='PCM_24')
#
# File ~/Documents/SPAI/repo/WAVFiles/Sweeps/6MIC/lib.py:109, in ess_parse_farina(sweep, inverse, t_sweep, t_idle, fs, causality)
#      82 def ess_parse_farina(sweep: np.ndarray, inverse: np.ndarray, t_sweep: float,
#      83                      t_idle: float, fs: int, causality: bool = False
#      84                      ) -> np.ndarray:
#      85     """
#      86     Process the input Exponential Sine Sweep (ESS) and output the
#      87     resulting Room Impulse Response (RIR) according to Farina [1].
#    (...)
#     107             The resulting Room Impulse Response.
#     108     """
# --> 109     if sweep.ndim > 1:
#     110         raise Exception("Input has more than one dimension. Please input"
#     111                         "a one dimensional vector containing the ESS.")
#     112     duration = int(np.floor((t_sweep + t_idle) * fs))
#
# AttributeError: 'tuple' object has no attribute 'ndim'

# %% [raw]
# ###############################################################################
# # Plot the calculated impulse response
# ###############################################################################

# %%
plt.figure()
t = np.arange(0, T_idle * fs) / fs
plt.plot(t, h)
plt.title('Impulse Response $\\delta(t)$')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.grid()
plt.show()

# %% [raw]
# ###############################################################################
# # Save the sweep and inverse filter to a file for later use
# ###############################################################################

# %%
#sf.write('sweep_192KHZ.wav', sweep, fs, subtype='PCM_24')
#sf.write("inverse_192KHZ.wav", inverse, fs, subtype='PCM_24')
